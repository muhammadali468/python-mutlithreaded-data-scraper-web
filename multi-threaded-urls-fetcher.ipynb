# %%
#libraries
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor

# %%
#Function to fetch url

# %%
def scrape_page(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        links = soup.find_all('html')
        print(f"Scraped {url}, found {len(links)} links.")
        print(f"Links : {links}.")
    except Exception as e:
        print(f"Error scrapping {url} : {e}")

# %%
#Mutli threaded scraper

# %%
def multi_threaded_scraper(urls,num_threads):
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        executor.map(scrape_page, urls)

# %%
#urls

# %%
url_list = ["https://www.geo.tv/","https://www.express.pk/","https://arynews.tv/"]

# %%
num_threads = len(url_list)

# %%
if __name__ == "__main__":
    multi_threaded_scraper(url_list,len(url_list))
# Out:
# Scraped https://www.express.pk/, found 1 links.
# Links : [<html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head profile="https://www.express.pk">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <title>Express News | Express News Urdu | Latest Urdu News</title>
# <meta content=" Latest urdu news, breaking news, current news in urdu from Pakistan, World, Sports, Business, Cricket , Politics and Weather only at Express News." name="description"/>
# <script defer="" type="application/ld+json">
#                 {
#                     "@context":"http://schema.org",
#                     "@type":"organization",
#                     "logo":"https://c.express.pk/2023/08/0-expresslogo-1692863088.png",
#                     "name":"Express News",
#                     "url":"https://www.express.pk/",
#                     "sameAs":[
#                         "https://www.facebook.com/expressnewspk",
#                         "https://twitter.com/ExpressNewsPK",
#                     ]
#                 }
#             </script>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <!--[if lte IE 7]>
#                 <![endif]-->
# <!--[if lte IE 6]>
#                         <script type="text/javascript" src="https://www.express.pk/wp-content/themes/express-v5/js/DD_belatedPNG.js"></script>
#                 <script type="text/javascript">
#                         try {
#                                 DD_belatedPNG.fix('img, #header ');
#                         }
#                         catch(err){}
#                 </script>
#         <![endif]-->
# <link href="https://www.express.pk/feed/" rel="alternate" title="ایکسپریس اردو RSS Feed" type="application/rss+xml"/>
# <link href="https://www.express.pk/application/xmlrpc.php" rel="pingback"/>
# <meta content="770767426360150" property="fb:app_id">
# <meta content="152904740527" property="fb:pages"/>
# <script>
#     (function(d, s, id){
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.3&appId=770767426360150";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
# </script>
# <script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
# </script>
# <script>
#     var isMobile = false; //initiate as false
#     // device detection
#     isMobile = (/android|webos|iphone|ipad|ipod|blackberry|iemobile|opera mini/i.test(navigator.userAgent.toLowerCase()));
#     if(isMobile==false){
#         isMobile = 'Desktop';
#     }else{
#         isMobile = 'Mobile';
#     }
# </script>
# <script async="async">
#         googletag.cmd.push(function() {
#             var mapping_lb = googletag.sizeMapping()
#                 .addSize([1024, 0], [[970,250],[970, 90], [728, 90]])
#                 .addSize([740, 0], [728, 90])
#                 .addSize([320, 0], [[320, 50] , [320, 100]])
#                 .addSize([0, 0], [320, 50])
#                 .build();
#             var mapping_1 = googletag.sizeMapping()
#                 .addSize([1024, 0], [728, 90])
#                 .addSize([740, 0], [728, 90])
#                 .addSize([320, 0], [[320, 50], [300, 250], [320, 100]])
#                 .addSize([0, 0], [320, 50])
#                 .build();
#
#             var mapping_2 = googletag.sizeMapping()
#                 .addSize([1024, 0], [[300, 600], [300, 250], [160, 600], [120, 600]])
#                 .addSize([740, 0], [[300, 600], [300, 250], [160, 600], [120, 600]])
#                 .addSize([320, 0], [[300, 250], [320,100], [320, 50]])
#                 .addSize([0, 0], [300, 250])
#                 .build();
#
#             var mapping_4 = googletag.sizeMapping()
#                 .addSize([1024, 0],[[300, 250], [320, 480], [336, 280]])
#                 .addSize([336, 0], [[300, 250], [320, 480], [320, 100], [320, 50], [336, 280]])
#                 .addSize([320, 0], [[300, 250], [320, 480], [320, 100], [320, 50]])
#                 .addSize([300, 0], [[300, 250], [300, 100]])
#                 .build();
#
#
#
#             googletag.defineSlot('/11952262/express-home-lb-1', [970, 250], 'div-gpt-lb-1').addService(googletag.pubads())
#                 .defineSizeMapping(mapping_lb)
#                 .setTargeting("pos", "atf");
#
#             googletag.defineSlot('/11952262/express-home-mrec-1', [336, 280], 'div-gpt-mrec-1').addService(googletag.pubads())
#                 .defineSizeMapping(mapping_4)
#                 .setTargeting("pos", "atf");
#
#             googletag.defineSlot('/11952262/express-home-mrec-2', [300, 600], 'div-gpt-mrec-2').addService(googletag.pubads())
#                 .defineSizeMapping(mapping_2)
#                 .setTargeting("pos", "btf");
#
#
#
#                         googletag.pubads().setTargeting('site', ['expresspk']);
#             googletag.pubads().setTargeting('Express_Page', ['home']);
#             googletag.pubads().setTargeting('device', [isMobile]);
#             googletag.pubads().enableSingleRequest();
#             googletag.pubads().collapseEmptyDivs(true);
#             googletag.enableServices();
#         });
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-VY07HQKFFY"></script>
# <script>
# 		window.dataLayer = window.dataLayer || [];
# 		function gtag(){dataLayer.push(arguments);}
# 		gtag('js', new Date());
#
# 		gtag('config', 'G-VY07HQKFFY');
#         gtag('config', 'G-KYMER0PVRK');
# </script>
# <meta content="Follow Express News for latest urdu news, Pakistan news, breaking news, current news in urdu from Pakistan, World, Sports, Business, Cricket, Politics and Weather only at Express News Channel." name="description"/>
# <link href="https://www.express.pk" rel="canonical"/>
# <link href="https://www.express.pk/page/2/" rel="next"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="Express News | Express News Urdu | Latest Urdu News" property="og:title"/>
# <meta content="Follow Express News for latest urdu news, Pakistan news, breaking news, current news in urdu from Pakistan, World, Sports, Business, Cricket, Politics and Weather only at Express News Channel." property="og:description"/>
# <meta content="/" property="og:url"/>
# <meta content="ایکسپریس اردو" property="og:site_name"/>
# <script type="application/ld+json">{ "@context": "http://schema.org","@type": "WebSite","url": "https://www.express.pk/","potentialAction": {"@type": "SearchAction","target": "https://www.express.pk/?s={search_term}","query-input": "required name=search_term"}}</script>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/72x72\/","ext":".png","source":{"concatemoji":"https:\/\/www.express.pk\/application\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.2.5"}};
# 			!function(a,b,c){function d(a){var c=b.createElement("canvas"),d=c.getContext&&c.getContext("2d");return d&&d.fillText?(d.textBaseline="top",d.font="600 32px Arial","flag"===a?(d.fillText(String.fromCharCode(55356,56812,55356,56807),0,0),c.toDataURL().length>3e3):(d.fillText(String.fromCharCode(55357,56835),0,0),0!==d.getImageData(16,16,1,1).data[0])):!1}function e(a){var c=b.createElement("script");c.src=a,c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var f,g;c.supports={simple:d("simple"),flag:d("flag")},c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.simple&&c.supports.flag||(g=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",g,!1),a.addEventListener("load",g,!1)):(a.attachEvent("onload",g),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),f=c.source||{},f.concatemoji?e(f.concatemoji):f.wpemoji&&f.twemoji&&(e(f.twemoji),e(f.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://www.express.pk/wp-content/plugins/u-more-recent-posts/inc/style.css?ver=1.4.2" id="umrp-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.express.pk/wp-content/plugins/category-posts/cat-posts.css?ver=4.2.5" id="category-posts-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.express.pk/wp-content/plugins/express-mobile-sharebar/css/mobile_sharebar.css?v=1.2&amp;ver=4.2.5" id="mobile_share-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.express.pk/wp-content/plugins/featured-top-stories/css/featured-top-stories.css?ver=4.2.5" id="style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.express.pk/wp-content/plugins/wp-polls/polls-css.css?ver=2.68" id="wp-polls-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.express.pk/wp-content/plugins/express-popular-posts/style/wpp.css?ver=3.3.4" id="wordpress-popular-posts-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://www.express.pk/application/wp-includes/js/jquery/jquery.js?ver=1.11.2" type="text/javascript"></script>
# <script async="" defer="defer" src="https://www.express.pk/application/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.2.1" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var umrp_vars = {"ajaxurl":"https:\/\/www.express.pk\/application\/wp-admin\/admin-ajax.php","nonce":"f30c671a19"};
# var umrp_vars = {"ajaxurl":"https:\/\/www.express.pk\/application\/wp-admin\/admin-ajax.php","nonce":"f30c671a19"};
# /* ]]> */
# </script>
# <script async="" defer="defer" src="https://www.express.pk/wp-content/plugins/u-more-recent-posts/inc/script.js?ver=1.4.2" type="text/javascript"></script>
# <script async="" defer="defer" src="https://www.express.pk/wp-content/plugins/special-story/js/special-story.js?ver=1.1" type="text/javascript"></script>
# <script async="" defer="defer" src="https://www.express.pk/wp-content/plugins/express-mobile-sharebar/js/mobile_sharebar.js?ver=4.2.5" type="text/javascript"></script>
# <script async="" defer="defer" src="https://www.express.pk/wp-content/plugins/video-management/js/main.js?ver=1.2" type="text/javascript"></script>
# <link href="https://www.express.pk/application/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://www.express.pk/application/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 4.2.5" name="generator"/>
# <meta content="Alkivia Framework 0.8" name="framework"/>
# <style type="text/css">
# .wp-polls .pollbar {
# 	margin: 1px;
# 	font-size: 14px;
# 	line-height: 16px;
# 	height: 16px;
# 	background: #006db5;
# 	border: 1px solid #ffffff;
# }
# </style>
# <link href="https://www.express.pk/wp-content/themes/express-v5/css/css.php?type=main,ie,ie6&amp;ver=20190326" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://www.express.pk/wp-content/themes/express-v5/css/css.php?type=print&amp;ver=20190326" media="print" rel="stylesheet" type="text/css"/>
# <meta content="کل تک ۔ 07 دسمبر ۔ 2023ء" property="og:title"/><meta content="https://i.ytimg.com/vi/ANYcLVXKR_g/hqdefault.jpg" property="og:image"/><meta content="https://www.express.pk/story/2575659/1" property="og:url"/><meta content="" property="og:description"/> <script type="text/javascript">
#         var addthis_share = { templates: { twitter: "{{title}} - {{url}}" } };
#
#     </script>
# <script type="text/javascript">var _sf_startpt = (new Date()).getTime()</script>
# <script src="https://www.express.pk/wp-content/themes/express-v5/js/jquery.cycle.lite.js"></script>
# <script src="https://www.express.pk/wp-content/themes/express-v5/js/jquery.UrduEditor.js" type="text/javascript"></script>
# <link href="https://www.express.pk/wp-content/themes/express-v5/css/wmd.css" rel="stylesheet" type="text/css"/>
# <script src="https://www.express.pk/wp-content/themes/express-v5/js/showdown.js"></script>
# <script src="https://www.express.pk/wp-content/themes/express-v5/js/rad.min.js"></script>
# <style>
#         .logo-none-1 {
#             display: none;
#         }
#
#         #navigation ul#menu-main-menu li a {
#             font-size: 23px;
#             font-weight: 500;
#             line-height: 1.4;
#         }
#
#         .onpagemenu {
#             text-align: center;
#         }
#
#         .onpagemenu li {
#             padding-left: 35px;
#             font-size: 21px;
#             font-weight: 700;
#             display: inline;
#         }
#
#         .beta {
#             display: none;
#         }
#     </style>
# <meta content="600" http-equiv="refresh"/> </meta></meta></head>
# <body class="">
# <div class="fb-quote"></div>
# <div class="wrapper-box">
# <div class="container home blog psl-bg-clr cont-paddin ham-sticky">
# <style>
#                 .wrapper-box {
#                     max-width: 1170px;
#                     margin: 0 auto;
#                 }
#
#                 div.topArea {
#                     width: 100%;
#                     position: relative;
#                     background: #b92533;
#                     margin-bottom: 3px;
#                     max-height: 305px;
#                 }
#
#                 #socialshare {
#                     text-align: center;
#                 }
#
#                 div#content h1.title {
#                     font-size: 30px;
#                 }
#
#                 .columnarstorey .cstoreyitem a {
#                     font-size: 20px;
#                 }
#
#                 div#content h2.title {
#                     font-size: 30px;
#                 }
#
#                 .top-stories-image {
#                     font-size: 20px;
#                 }
#
#                 .meta span.timestamp {
#                     padding-right: 10px;
#                 }
#
#                 .cstoreyitem a {
#                     font-size: 20px;
#                 }
#
#
#                 a.ss-button span,
#                 .mail_to_,
#                 a.share span.cm {
#                     background-position-y: 8px !important;
#                 }
#
#                 #navigation ul#menu-main-menu li a {
#                     font-size: 22px;
#                 }
#
#                 < !-- .banner-fixed-cricketpakistan.f-ban-right {
#                     right: -90px;
#                     left: inherit;
#                 }
#
#                 -->< !-- .banner-fixed-cricketpakistan {
#                     display: none;
#                 }
#
#                 -->p.jwp-s {
#                     position: relative;
#                     padding-bottom: 53.25%;
#                     padding-top: 25px;
#                     height: 0;
#                 }
#
#                 @media screen and (min-width:992px) {
#
#                     jwp-s iframe {
#                         position: absolute;
#                         top: 0;
#                         right: 0;
#                         width: 70%;
#                         height: 70%;
#                     }
#                 }
#
#                 @media screen and (max-width:991px) {
#                     .jwp-s iframe {
#                         width: 100%;
#                         height: 100%;
#                         position: absolute;
#                         top: 0;
#                         right: 0;
#                     }
#                 }
#
#                 @media (max-width:590px) {
#                     div#taboola-below-article-thumbnails {
#                         max-height: 1157px;
#                         overflow: hidden;
#                     }
#
#                     .cstoreyitem {
#                         width: 100% !important;
#                     }
#                 }
#
#                 div#taboola-below-article-thumbnails-1 {
#                     /*max-height: 375px;*/
#                     overflow: hidden;
#                 }
#
#                 @media screen and (min-width: 500px) {
#                     div#taboola-below-article-thumbnails-1 {
#                         max-height: 765px;
#                         overflow: hidden;
#                     }
#                 }
#             </style>
# <div class="topArea">
# <div class="brands-bar">
# <div class="menu-brand-bar-container"><ul class="menu" id="menu-brand-bar"><li class="first" id="menu-item-416041"><a href="https://tribune.com.pk/">Express Tribune</a></li>
# <li id="menu-item-416043"><a href="https://express.com.pk/epaper/">Urdu E-Paper</a></li>
# <li id="menu-item-416044"><a href="https://tribune.com.pk/epaper/">English E-Paper</a></li>
# <li id="menu-item-416040"><a href="https://www.sindhexpress.com.pk/">Sindhi E-Paper</a></li>
# <li class="last" id="menu-item-416045"><a href="https://express.pk/live/">Live Streaming</a></li>
# <li class="last" id="menu-item-1174752"><a href="https://www.expressentertainment.tv/">Express Entertainment</a></li>
# </ul></div>
# </div>
# <div class="clearfix"></div>
# <div class="top">
# <div class="social-links">
# <ul>
# <li><a href="https://www.facebook.com/expressnewspk" target="_blank"><img class="img-responsive" src="https://c.express.pk/2023/08/0-fbx-1692861492.png"/></a></li>
# <li><a href="https://twitter.com/ExpressNewsPK" target="_blank"><img class="img-responsive" src="https://c.express.pk/2023/08/0-twiterx-1692861405.png"/></a></li>
# </ul>
# </div>
# <ul class="menu" id="menu-top-menu"><li class="date">جمعـء 8 دسمبر 2023</li><li class="beta last"> beta 1.0 </li></ul> </div>
# <div class="clearfix"></div>
# <div class="logo">
# <a href="https://www.express.pk" title="ایکسپریس اردو">
# <img alt="ایکسپریس اردو" class="img-responsive" src="https://c.express.pk/2023/08/0-expresslogo-1692863088.png">
# </img></a>
# </div>
# <div class="clearfix"></div>
# <div class="span-24" id="navigation">
# <nav class="navbar navbar-default pull-right" role="navigation">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <img class="img-responsive" src="https://www.express.pk/wp-content/themes/express-v5/img/mobile-menu.png"/>
# </button>
# <a class="navbar-brand" href="#"></a>
# </div>
# <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
# <ul class="nav navbar-nav" id="menu-main-menu"><li class="first home menu-item-has-children current" id="menu-item-931105"><a href="https://www.express.pk/">صفحۂ اول</a></li>
# <li id="menu-item-2336960"><a href="https://www.express.pk/latest-news/">تازہ ترین</a></li>
# <li class="pakistan menu-item-has-children" id="menu-item-2441"><a href="https://www.express.pk/pakistan/">پاکستان</a></li>
# <li class="world" id="menu-item-64"><a href="https://www.express.pk/world/">انٹر نیشنل</a></li>
# <li id="menu-item-1701014"><a href="https://cricketpakistan.com.pk/ur/" target="_blank">کرکٹ</a></li>
# <li class="sports" id="menu-item-84"><a href="https://www.express.pk/sports/">کھیل</a></li>
# <li class="style" id="menu-item-69"><a href="https://www.express.pk/saqafat/">انٹرٹینمنٹ</a></li>
# <li class="weird-news" id="menu-item-262378"><a href="https://www.express.pk/weird-news/">دلچسپ و عجیب</a></li>
# <li id="menu-item-263167"><a href="https://www.express.pk/science/">سائنس و ٹیکنالوجی</a></li>
# <li class="health" id="menu-item-337757"><a href="https://www.express.pk/health/">صحت</a></li>
# <li class="business last" id="menu-item-63"><a href="https://www.express.pk/business/">بزنس</a></li>
# <li class="last" id="menu-item-235572"><a href="https://www.express.pk/blog/">بلاگ</a></li>
# <li class="last" id="menu-item-297819"><a href="https://www.express.pk/videos/">ویڈیوز</a></li>
# </ul> </div>
# </nav>
# <div class="span-24" id="sub-nav">
# <ul class="span-24 subcategory" id="sub-menu"> <li class="first" id="menu-item-1093642"><a href="https://www.express.pk/religion/">دین ودنیا</a></li>
# <li id="menu-item-1093636"><a href="https://www.express.pk/magazine/">میگزین</a></li>
# <li id="menu-item-2187631"><a href="https://food.tribune.com.pk/ur/">فوڈ</a></li>
# <li id="menu-item-2129110"><a href="https://www.express.pk/crime/">جرائم</a></li>
# <li class="last" id="menu-item-1093638"><a href="https://www.express.pk/opinion/">رائے</a></li>
# </ul> </div>
# </div>
# </div>
# <div class="span-24" id="tickerbox">
# <div class="label"> تازہ ترین </div>
# <div class="text">
# <div id="tickertext">

# </div>
# <div class="clearfix"></div>
# </div>
# <div class="controls"> <img alt="&lt;" class="prev" src="https://www.express.pk/wp-content/themes/express-v5/img/left-arrow-thin.gif"> <img alt="&gt;" class="next" src="https://www.express.pk/wp-content/themes/express-v5/img/right-arrow-thin.gif"> </img></img></div>
# </div>
# <div class="live-express-logo">
# <a href="https://live.express.pk" title="ایکسپریس اردو">
# <img border="0" src="https://www.express.pk/wp-content/themes/express-v5/img/tv-icon.png"/>
# <img border="0" src="https://www.express.pk/wp-content/themes/express-v5/img/live-tv.png"/>
# </a>
# <script src="https://apis.google.com/js/platform.js"></script>
# <div class="g-ytsubscribe" data-channelid="UCTur7oM6mLL0rM2k0znuZpQ" data-count="default" data-layout="default"></div>
# </div>
# </div>
# <div class="ad-none" style="margin: 0 auto;padding:10px;background: white;">
# <div id="div-gpt-lb-1" style="display:table; margin:0px auto;">
# <script>
#                                 googletag.cmd.push(function () { googletag.display("div-gpt-lb-1"); });
#                             </script>
# </div>
# </div>
# <div class="container home blog">
# <div class="span-24" id="content">
# <div class="primary span-16 last">
# <div class="main clearfix group">
# <!--[if IE 8]>
# <style>
#     .author .primary H1.title {
# 	border-bottom-style: none!important;
# 	margin-bottom: 0px;
# }
# </style>
# <![endif]-->
# <div class="story manageable cat-0 group-0 position-0" id="id-2575659">
# <div class="span-8 mobile-view-home-top" style="float: right;"> <h1 class="title span-8">
# <a href="https://www.express.pk/story/2575659/1">انتخابات: ن لیگ اوراستحکام پاکستان کے درمیان سیٹ ایڈجسٹمنٹ پر اتفاق</a>
# </h1>
# <div ;="" class="content clearfix clear span-8" style="float:right">
# <div class="span-8 last mobile-view-image" style="float:right;">
# <a class="image live-text full-width-link" href="https://www.express.pk/story/2575659/1"> <img alt="فوتو: فائل " class="full-width-image" height="264" src="https://c.express.pk/2023/12/2575659-shahbaztareen-1702040912-583-640x480.jpg" width="352"/>
# </a>
# </div>
# <div class="span-8 last">
# <div class="meta">
# <span class="author"><a href="https://www.express.pk/author/29/web-desk/" title="ویب ڈیسک">ویب ڈیسک</a></span>
# <span class="timestamp" title="2023-12-08T13:11:30 GMT">جمعـء 8 دسمبر 2023</span>
# </div>
# <p class="excerpt">
# سیٹ ایڈجسٹمنٹ کتنی نشستوں پر ہوگی یہ طے کرنے لیے رہنماؤں کے درمیان مزید ملاقاتیں ہوں گی، پارٹی ذرائع </p>
# <span class="comment"><a class="comments" href="https://www.express.pk/story/2575659/1#comments" title="تبصرے">تبصرے</a></span>
# </div>
# </div>
# </div> <div class="span-7 featured-top-stories widget">
# <h3 class="group-title" style="background: none;text-align: center;border: none;">خاص خبریں</h3>
# <ul style="">
# <li>
# <a href="https://www.express.pk/story/2575569/16">
# <div class="top-stories-image">
# <img alt="ابرار احمد چار روزہ میچ میں انجری کا شکار ہوگئے (فوٹو: کرک انفو)" class="recent-posts-thumb" height="100" src="https://c.express.pk/2023/12/2575569-abrarahmed-1702023241-244-640x480.jpg" width="100"/>
# آسٹریلیا کیخلاف سیریز سے قبل قومی ٹیم کو بڑا دھچکا </div>
# </a>
# </li>
# <li>
# <a href="https://www.express.pk/story/2575611/24">
# <div class="top-stories-image">
# <img alt="فوٹو : فائل" class="recent-posts-thumb" height="100" src="https://c.express.pk/2023/12/2575611-ai-1702032925-349-640x480.jpg" width="100"/>
# طلاق کی افواہیں، امیتابھ بچن نے ایشوریا رائے کو اَن فالو کردیا </div>
# </a>
# </li>
# <li>
# <a href="https://www.express.pk/story/2575029/9812">
# <div class="top-stories-image">
# <img alt="[فائل-فوٹو]" class="recent-posts-thumb" height="100" src="https://c.express.pk/2023/12/2575029-shutterstock_-1701896087-250-640x480.jpg" width="100"/>
#  دن میں مختصر نیند لینا ضروری کیوں؟ </div>
# </a>
# </li>
# <li>
# <a href="https://www.express.pk/story/2575507/10">
# <div class="top-stories-image">
# <img alt="فوٹو : سوشل میڈیا" class="recent-posts-thumb" height="100" src="https://c.express.pk/2023/12/2575507-is-1702016005-455-640x480.jpg" width="100"/>
# مغوی فلسطینی شہریوں کیساتھ اسرائیلی فوج کا دردناک سلوک، ویڈیو وائرل </div>
# </a>
# </li>
# <li>
# <a href="https://www.express.pk/story/2575547/16">
# <div class="top-stories-image">
# <img alt="ڈیوڈ وارنر نے بھی تنقید کا جواب دیدیا (فوٹو: ایکسپریس ویب)" class="recent-posts-thumb" height="100" src="https://c.express.pk/2023/12/2575547-warnerandjohnson-1702019082-657-640x480.jpg" width="100"/>
# بال ٹیمپرنگ اسکینڈل میں پھنسنے والے وارنر کو فیئر ویل دینے پر مچل جانسن چراغ پَا </div>
# </a>
# </li>
# </ul>
# </div>
# <div style="clear:both"></div>
# </div><div class="last columnarstorey"> <h3 class="group-title"> خبریں </h3>
# <div class="cstoreyitem" id="id-2575612">
# <div>
# <a href="https://www.express.pk/story/2575612/1">
# <img alt="نواز شریف ن لیگ کے پارلیمانی بورڈ کے اجلاس کی صدارت کرتے ہوئے (فوٹو : پی ایم ایل این)" height="94" src="https://c.express.pk/2023/12/2575612-nawazsharifmeeting-1702032114-839-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575612/1">ملکی تاریخ میں کرپشن کا سب سے بڑا اسکینڈل 190 ملین پاؤنڈ کیس ہے، نواز شریف </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575619">
# <div>
# <a href="https://www.express.pk/story/2575619/1">
# <img alt="(فوٹو: فائل)" height="94" src="https://c.express.pk/2023/12/2575619-shaukattareen-1702036914-205-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575619/1">سابق وزیر خزانہ شوکت ترین بھی پی ٹی آئی کو خیرباد کہہ گئے </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575636">
# <div>
# <a href="https://www.express.pk/story/2575636/1">
# <img alt="(فوٹو : فائل)" height="94" src="https://c.express.pk/2023/12/2575636-sarfrazbugti-1702034991-676-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575636/1">کوئی غیرملکی سیاسی سرگرمیوں میں ملوث پایا تو ڈی پورٹ کردیں گے، نگراں وزیر داخلہ </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575490">
# <div>
# <a href="https://www.express.pk/story/2575490/6">
# <img alt="(فوٹو : فائل)" height="94" src="https://c.express.pk/2023/12/2575490-stockmarkethigh-1702012901-868-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575490/6">پاکستان اسٹاک ایکسچینج میں 66ہزار پوائنٹس کی سطح بھی عبور </a>
# <div class="meta">
# </div>
# </div>
# </div><br clear="all"/>
# <div class="cstoreyitem" id="id-2575580">
# <div>
# <a href="https://www.express.pk/story/2575580/1">
# <img alt="(فوٹو: اسکرین گریب)" height="94" src="https://c.express.pk/2023/12/2575580-murtazasolangi-1702030837-454-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575580/1">بانی پی ٹی آئی کو جیل میں ٹوئٹ کرنے کی سہولت میسر نہیں، وزیر اطلاعات </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575600">
# <div>
# <a href="https://www.express.pk/story/2575600/6">
# <img alt="(فوٹو : انٹرنیٹ)" height="94" src="https://c.express.pk/2023/12/2575600-oilandgasinsindh-1702029589-791-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575600/6">سندھ میں تیل اور گیس کے بڑے ذخائر دریافت </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575565">
# <div>
# <a href="https://www.express.pk/story/2575565/1">
# <img alt="(فوٹو: فائل)" height="94" src="https://c.express.pk/2023/12/2575565-sheikhrasheed-1702022397-749-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575565/1">شیخ رشید جی ایچ کیو حملہ سمیت 10 مقدمات میں نامزد، فہرست عدالت میں جمع </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575543">
# <div>
# <a href="https://www.express.pk/story/2575543/1">
# <img alt="(فوٹو: فائل)" height="94" src="https://c.express.pk/2023/12/2575543-ptiecp-1702020098-122-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575543/1">انٹرا پارٹی الیکشن کالعدم قرار دینے کی درخواست پر تحریک انصاف کو نوٹس </a>
# <div class="meta">
# </div>
# </div>
# </div> </div>
# </div>
# <div class="videos clearfix group carousel-parent">
# <h3 class="group-title">
# <a class="multimedia" href="https://www.express.pk/videos">ویڈیوز</a>
# </h3>
# <div class="content">
# <div class="slider1">
# <div class="slide">
# <a class="image" href="https://www.express.pk/videos/2575424/kal-tak-with-javed-chaudhry-7-december-2023-express-news/" title="کل تک ۔ 07 دسمبر ۔ 2023ء">
# <img alt="" class="img-responsive" src="https://i.ytimg.com/vi/ANYcLVXKR_g/hqdefault.jpg"/>
# </a>
# <p><a href="https://www.express.pk/videos/2575424/kal-tak-with-javed-chaudhry-7-december-2023-express-news/">کل تک ۔ 07 دسمبر ۔ 2023ء</a></p>
# </div>
# <div class="slide">
# <a class="image" href="https://www.express.pk/videos/2575415/center-stage-with-rehman-azhar-7-december-2023-express-news/" title="سینٹر اسٹیج ۔ 07 دسمبر ۔ 2023ء">
# <img alt="" class="img-responsive" src="https://i.ytimg.com/vi/6kzbEMFqcbQ/hqdefault.jpg"/>
# </a>
# <p><a href="https://www.express.pk/videos/2575415/center-stage-with-rehman-azhar-7-december-2023-express-news/">سینٹر اسٹیج ۔ 07 دسمبر ۔ 2023ء</a></p>
# </div>
# <div class="slide">
# <a class="image" href="https://www.express.pk/videos/2575356/pml-n-big-political-move-chairman-pti-faces-problems-express-expert-express-news/" title="ایکسپریس ایکسپرٹس ۔ 07 دسمبر ۔ 2023ء">
# <img alt="" class="img-responsive" src="https://i.ytimg.com/vi/a8wFtX3H8uM/hqdefault.jpg"/>
160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575546/1">190 ملین پاؤنڈ کرپشن کیس: عمران خان کے شریک ملزمان کے اشتہار جاری </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575592">
# <div>
# <a href="https://www.express.pk/story/2575592/1">
# <img alt="گرفتار ملزم کی تصویر اور برآمد اسلحہ (فوٹو : سی ٹی ڈی)" height="94" src="https://c.express.pk/2023/12/2575592-ttpsawatameerarrest-1702028033-417-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575592/1">دہشت گردی کی بڑی کارروائیوں میں ملوث ٹی ٹی پی سوات کا امیر گرفتار </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575543">
# <div>
# <a href="https://www.express.pk/story/2575543/1">
# <img alt="(فوٹو: فائل)" height="94" src="https://c.express.pk/2023/12/2575543-ptiecp-1702020098-122-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575543/1">انٹرا پارٹی الیکشن کالعدم قرار دینے کی درخواست پر تحریک انصاف کو نوٹس </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575614">
# <div>
# <a href="https://www.express.pk/story/2575614/1">
# <img alt="(فوٹو : فائل)" height="94" src="https://c.express.pk/2023/12/2575614-twoarrestwomenandmen-1702033684-480-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575614/1">خاتون کو بلیک میل کرنے والی ملزمہ سمیت تین گرفتار، جعلی پریس کارڈز برآمد </a>
# <div class="meta">
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# <div class="world clearfix group">
# <h3 class="group-title">
# <a href="https://www.express.pk/world/">انٹر نیشنل</a>
# </h3>
# <div class="clearfix top-story clear">
# <div class="story manageable cat-10 group-0 position-0 first last" id="id-2575603">
# <h2 class="title">
# <a href="https://www.express.pk/story/2575603/10">غزہ؛ حماس سے لڑائی میں اسرائیل کے سابق آرمی چیف کا بیٹا ہلاک</a>
# </h2>
# <div class="content clearfix">
# <div class="span-8" style="float:right;">
# <a class="image mobile-top-story-image" href="https://www.express.pk/story/2575603/10">
# <img alt="سابق آرمی چیف نے اپنے فوجی بیٹے کی ہلاکت کا واقعہ اسکرین پر براہ راست دیکھا، فوٹو: فائل  " height="229" src="https://c.express.pk/2023/12/2575603-israel-1702032510-254-640x480.jpg" width="305"/>
# </a>
# </div>
# <div class="span-7 last">
# <div class="meta">
# <span class="author"><a href="https://www.express.pk/author/29/web-desk/" title="ویب ڈیسک">ویب ڈیسک</a></span>
# <span class="timestamp" title="2023-12-08T10:51:52 GMT">جمعـء 8 دسمبر 2023</span>
# </div>
# <p class="excerpt">
# سابق آرمی چیف اور موجودہ جنگی نگراں نے اپنے فوجی بیٹے کی ہلاکت کا واقعہ اسکرین پر براہ راست دیکھا </p>
# <a class="comments" href="https://www.express.pk/story/2575603/10#comments" title="تبصرے">تبصرے</a>
# <ul class="links related-stories">
# </ul>
# </div>
# </div>
# </div> </div>
# <div class="clearfix clr">
# <div class="span-16 last">
# <div class="cstoreyitem" id="id-2575658">
# <div>
# <a href="https://www.express.pk/story/2575658/10">
# <img alt="اقوام متحدہ کی جنرل اسمبلی میں فلسطینیوں کے حق میں 5 قراردادیں منظور کرلی گئیں، فوٹو: فائل " height="94" src="https://c.express.pk/2023/12/2575658-unga-1702040563-969-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2
160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2574704/16">چار روزہ میچ؛ آسٹریلیا پرائم منسٹر الیون کی برتری، پاکستانی بالرز نے گھٹنے ٹیک دیے </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575582">
# <div>
# <a href="https://www.express.pk/story/2575582/16">
# <img alt="لیجنڈز لیگ کرکٹ کے کمشنر نے فاسٹ بولر کو قانونی نوٹس بھجوادیا (فوٹو: ایکسپریس ویب)" height="94" src="https://c.express.pk/2023/12/2575582-gambhirandsreesanth-1702024618-198-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575582/16">گمبھیر کیخلاف ویڈیو اَپ لوڈ کرنا سری سانتھ کو مہنگا پڑگیا </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575547">
# <div>
# <a href="https://www.express.pk/story/2575547/16">
# <img alt="ڈیوڈ وارنر نے بھی تنقید کا جواب دیدیا (فوٹو: ایکسپریس ویب)" height="94" src="https://c.express.pk/2023/12/2575547-warnerandjohnson-1702019082-657-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575547/16">بال ٹیمپرنگ اسکینڈل میں پھنسنے والے وارنر کو فیئر ویل دینے پر مچل جانسن چراغ پَا </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575521">
# <div>
# <a href="https://www.express.pk/story/2575521/16">
# <img alt="وسیم اکرم نے حارث رؤف کو خبردار کردیا (فوٹو: ایکسپریس ویب)" height="94" src="https://c.express.pk/2023/12/2575521-harisandwasim-1702016058-809-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575521/16">’’نامور کھلاڑیوں کیساتھ جگہ چاہیے تو ٹیسٹ کرکٹ کھیلنا ہوگی‘‘ </a>
# <div class="meta">
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# <div class="saqafat clearfix group">
# <h3 class="group-title">
# <a href="https://www.express.pk/saqafat/">انٹرٹینمنٹ</a>
# </h3>
# <div class="clearfix top-story clear">
# <div class="story manageable cat-24 group-0 position-0 first last" id="id-2575653">
# <h2 class="title">
# <a href="https://www.express.pk/story/2575653/24">ریڈ سی انٹرنیشنل میں پاکستانی فلم ’اِن فلیمز‘ نے ’بیسٹ فیچر فلم‘ کا ایوارڈ جیت لیا</a>
# </h2>
# <div class="content clearfix">
# <div class="span-8" style="float:right;">
# <a class="image mobile-top-story-image" href="https://www.express.pk/story/2575653/24">
# <img alt="فوٹو : انسٹاگرام" height="229" src="https://c.express.pk/2023/12/2575653-image-1702038082-167-640x480.png" width="305"/>
# </a>
# </div>
# <div class="span-7 last">
# <div class="meta">
# <span class="author"><a href="https://www.express.pk/author/29/web-desk/" title="ویب ڈیسک">ویب ڈیسک</a></span>
# <span class="timestamp" title="2023-12-08T12:54:05 GMT">جمعـء 8 دسمبر 2023</span>
# </div>
# <p class="excerpt">
# پاکستان کی طرف سے ہمایوں سعید، ماہرہ خان اور احد رضا میر نے فیسٹیول کو رونق بخشی </p>
# <a class="comments" href="https://www.express.pk/story/2575653/24#comments" title="تبصرے">تبصرے</a>
# <ul class="links related-stories">
# </ul>
# </div>
# </div>
# </div> </div>
# <div class="clearfix clr">
# <div class="span-16 last">
# <div class="cstoreyitem" id="id-2575611">
# <div>
# <a href="https://www.express.pk/story/2575611/24">
# <img alt="فوٹو : فائل" height="94" src="https://c.express.pk/2023/12/2575611-ai-1702032925-349-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575611/24">طلاق کی افواہیں، امیتابھ بچن نے ایشوریا رائے کو اَن فالو کردیا </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575581">
# <div>
# <a href="https://www.express.pk/story/2575581/24">
# <img alt="فوٹو : بھارتی میڈیا" height="94" src="https://c.express.pk/2023/12/2575581-cin-1702026307-331-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575581/24">کینیڈا، بالی ووڈ فلمیں چلانے والے 3 سینما گھروں پر حملہ </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575556">
# <div>
# <a href="https://www.express.pk/story/2575556/24">
# <img alt="فوٹو : ایکس" height="94" src="https://c.express.pk/2023/12/2575556-nk-1702023139-756-160x120.jpg" width="125"/>
# </a>
# <a href="https://www.express.pk/story/2575556/24">نوجوت سنگھ سدھو کے بیٹے نے شادی کرلی </a>
# <div class="meta">
# </div>
# </div>
# </div>
# <div class="cstoreyitem" id="id-2575532">
# <div>
# <a href="https://www.express.pk/story/2575532/24">
# ...
# </div><div class="col-md-3 col-sm-6 col-ms-12">
# <div class="catPostHome" data-vr-zone="Home Category Pakistan Section">
# <div class="tittle-top">
# <h2><a href="https://www.geo.tv/category/sci-tech">Sci-Tech</a></h2>
# </div>
# <ul class="list"> <li class="border-box">
# <div class="top-story-first">
# <a class="open-section cat-open" data-article_name="Game Awards 2023: Why fantasy RPG 'Baldur's Gate 3' outgamed best of the best?" data-event_action="" data-position="1" data-vr-contentbox="Home  1" data-vr-contentbox-url="https://www.geo.tv/latest/522212-game-awards-2023-why-baldurs-gate-3-outgamed-best-of-the-best" href="https://www.geo.tv/latest/522212-game-awards-2023-why-baldurs-gate-3-outgamed-best-of-the-best" style="display: block;" title="Game Awards 2023: Why fantasy RPG 'Baldur's Gate 3' outgamed best of the best?">
# <img alt="Game Awards 2023: Why fantasy RPG 'Baldur's Gate 3' outgamed best of the best?" class="lazyload" data-src="https://www.geo.tv/assets/uploads/updates/2023-12-08/t_522212_053815_updates.jpg" src="https://www.geo.tv/assets/front/images/placeholders/300x255.png" title="Game Awards 2023: Why fantasy RPG 'Baldur's Gate 3' outgamed best of the best?"/>
# </a>
# <div class="main-heading-top">
# <h2 data-vr-headline="">
# <a class="open-section" data-article_name="Game Awards 2023: Why fantasy RPG 'Baldur's Gate 3' outgamed best of the best?" data-event_action="" data-position="1" data-vr-contentbox="Home  1" data-vr-contentbox-url="https://www.geo.tv/latest/522212-game-awards-2023-why-baldurs-gate-3-outgamed-best-of-the-best" href="https://www.geo.tv/latest/522212-game-awards-2023-why-baldurs-gate-3-outgamed-best-of-the-best" title="Game Awards 2023: Why fantasy RPG 'Baldur's Gate 3' outgamed best of the best?">
# Game Awards 2023: Why fantasy RPG 'Baldur's Gate 3' outgamed best of the best? </a>
# </h2>
# </div>
# </div>
# </li>
# <li class="border-box"><a class="open-section" data-article_name="Meta introduces default end-to-end encryption for Facebook, Messenger" data-event_action="" data-position="2" data-vr-contentbox="Home  2" data-vr-contentbox-url="https://www.geo.tv/latest/522210-meta-introduces-default-end-to-end-encryption-for-facebook-messenger" href="https://www.geo.tv/latest/522210-meta-introduces-default-end-to-end-encryption-for-facebook-messenger" title="Meta introduces default end-to-end encryption for Facebook, Messenger">Meta introduces default end-to-end encryption for Facebook, Messenger</a></li><li class="border-box"><a class="open-section" data-article_name="WhatsApp users can now filter chats with this new feature " data-event_action="" data-position="3" data-vr-contentbox="Home  3" data-vr-contentbox-url="https://www.geo.tv/latest/522194-whatsapp-users-can-now-filter-chats-with-this-new-feature" href="https://www.geo.tv/latest/522194-whatsapp-users-can-now-filter-chats-with-this-new-feature" title="WhatsApp users can now filter chats with this new feature ">WhatsApp users can now filter chats with this new feature </a></li><li class="border-box"><a class="open-section" data-article_name="Zindagi Trust gets featured on Meta website for transforming Pakistan's education system" data-event_action="" data-position="4" data-vr-contentbox="Home  4" data-vr-contentbox-url="https://www.geo.tv/latest/522098-shehzad-roys-zindagi-trust-features-on-metas-website-for-transforming-pakistan-education-system" href="https://www.geo.tv/latest/522098-shehzad-roys-zindagi-trust-features-on-metas-website-for-transforming-pakistan-education-system" title="Zindagi Trust gets featured on Meta website for transforming Pakistan's education system">Zindagi Trust gets featured on Meta website for transforming Pakistan's education system</a></li></ul> </div>
# </div> </div>
# </div>
# </section>
# <div class="clearfix"></div> <div class="clearfix"></div>
# <footer>
# <div class="container">
# <div class="ftr_inr">
# <div class="ftr_col">
# <h1>Sections</h1>
# <ul>
# <li><a data-event="tvc_bottom_navigation" data-event_action="Home" data-page_type="Homepage" href="https://www.geo.tv/" onclick="analyticsFunc(this)">Home</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="Latest" data-page_type="Listing Page" href="https://www.geo.tv/latest-news" onclick="analyticsFunc(this)">LATEST</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="Pakistan" data-page_type="Listing Page" href="https://www.geo.tv/category/pakistan" onclick="analyticsFunc(this)">PAKISTAN</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="World" data-page_type="Listing Page" href="https://www.geo.tv/category/world" onclick="analyticsFunc(this)">WORLD</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="SPORTS" data-page_type="Listing Page" href="https://www.geo.tv/category/sports" onclick="analyticsFunc(this)">SPORTS</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="ENTERTAINMENT" data-page_type="Listing Page" href="https://www.geo.tv/category/entertainment" onclick="analyticsFunc(this)">ENTERTAINMENT</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="BUSINESS" data-page_type="Listing Page" href="https://www.geo.tv/category/business" onclick="analyticsFunc(this)">BUSINESS</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="HEALTH" data-page_type="Listing Page" href="https://www.geo.tv/category/health" onclick="analyticsFunc(this)">HEALTH</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="AMAZING" data-page_type="Listing Page" href="https://www.geo.tv/category/amazing" onclick="analyticsFunc(this)">AMAZING</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="SCI-TECH" data-page_type="Listing Page" href="https://www.geo.tv/category/sci-tech" onclick="analyticsFunc(this)">SCI-TECH</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="Life style" data-page_type="Listing Page" href="https://www.geo.tv/category/life-style" onclick="analyticsFunc(this)">life style</a> </li>
# </ul>
# </div>
# <div class="ftr_col">
# <ul style="margin-top: 32px;">
# <li><a data-event="tvc_bottom_navigation" data-event_action="TV SHOWS" data-page_type="Listing Page" href="https://www.geo.tv/tv-shows" onclick="analyticsFunc(this)">TV SHOWS</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="VIDEOS" data-page_type="Listing Page" href="https://www.geo.tv/videos" onclick="analyticsFunc(this)">VIDEOS</a> </li>
# <li><a data-event="tvc_top_navigation" data-event_action="GeoUrdu_click" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)" target="_blank">URDU</a> </li>
# <li><h1>LIVE</h1></li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="live_tv" data-page_type="Homepage" href="https://live.geo.tv/" onclick="analyticsFunc(this)" target="_blank">TV</a> </li>
# <li>
# <div class="fb-bot-btn">
# <div class="fb-messengermessageus" color="blue" id="fb-messengermessageus" messenger_app_id="1678638095724206" page_id="101059326616167" size="large" style="height: 27px;"></div>
# <script> window.fbAsyncInit = function () {
#                                     FB.init({appId: '1678638095724206', xfbml: true, version: 'v2.6'});
#                                 }</script>
# </div>
# </li>
# <li>
# <div class="fb-bot-btn">
# <div class="fb-messengermessageus" color="blue" id="fb-messengermessageus" messenger_app_id="1678638095724206" page_id="101059326616167" size="large" style="height: 27px;"></div>
# <script> window.fbAsyncInit = function () {
#                                     FB.init({appId: '1678638095724206', xfbml: true, version: 'v2.6'});
#                                 }</script>
# </div>
# </li>
# </ul>
# </div>
# <div class="ftr_col">
# <h1>ABOUT</h1>
# <ul>
# <li><a data-event="tvc_bottom_navigation" data-event_action="ABOUT US" data-page_type="Listing Page" href="https://www.geo.tv/about-us" onclick="analyticsFunc(this)">ABOUT US</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="PRIVACY POLICY" data-page_type="Listing Page" href="https://www.geo.tv/privacy-policy-and-tos" onclick="analyticsFunc(this)">PRIVACY POLICY</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="ADVERTISING GUIDE" data-page_type="Listing Page" href="https://www.geo.tv/ratecardonline" onclick="analyticsFunc(this)">ADVERTISING GUIDE</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="FAQ DISTRIBUTION" data-page_type="Listing Page" href="https://www.geo.tv/faq-distribution" onclick="analyticsFunc(this)">FAQ DISTRIBUTION</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="CORPORATE PROFILE" data-page_type="Listing Page" href="https://www.geo.tv/corporate-profile" onclick="analyticsFunc(this)">CORPORATE PROFILE</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="FAQ (GENERAL)" data-page_type="Listing Page" href="https://www.geo.tv/faq" onclick="analyticsFunc(this)">FAQ (GENERAL)</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="GEO TV SATELLITE" data-page_type="Listing Page" href="https://www.geo.tv/faq#_" onclick="analyticsFunc(this)">GEO TV SATELLITE
# PARAMETERS</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="CAREER" data-page_type="Homepage" href="https://talent.geo.tv/" onclick="analyticsFunc(this)" target="_blank">CAREER</a> </li>
# </ul>
# </div>
# <div class="ftr_col">
# <h1>MORE</h1>
# <ul>
# <li><a data-event="tvc_bottom_navigation" data-event_action="Schedule" data-page_type="Listing Page" href="https://www.geo.tv/schedule" onclick="analyticsFunc(this)">Schedule</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="GEO TALENT" data-page_type="Homepage" href="https://talent.geo.tv/" onclick="analyticsFunc(this)" rel="nofollow" target="_blank">GEO TALENT</a> </li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="GEO ASOOL" data-page_type="Homepage" href="https://asool.geo.tv/" onclick="analyticsFunc(this)" rel="nofollow" target="_blank">GEO ASOOL</a> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="copyright">
# <p>Copyright © 2023. Geo Television Network. All Rights Reserved.</p>
# </div>
# </footer>
# </div>
# <script type="text/javascript">
#         var BaseURL = 'https://www.geo.tv/';
#         var Page = 'home';
#         var sg = '';
#     </script>
# <script type="text/javascript">
#             //setTimeout(function(){ $('.medium-insert-images').find('figure').show() }, 3000);
#             var loadDeferredJS = function() {
#
#               var lazyloadjs = ['https://www.geo.tv/assets/front/js/lazysizes.min.js'];
#
#               var alljs = ['https://www.geo.tv/assets/front/ui/js/thirdparty.js?ver=133'];
#
#               var firebaseappjs = ['https://www.gstatic.com/firebasejs/7.1.0/firebase-app.js'];
#               var firebasejs = ['https://www.gstatic.com/firebasejs/7.1.0/firebase-analytics.js','https://www.gstatic.com/firebasejs/7.1.0/firebase-messaging.js'];
#               var firebasejs_tokenjs = ['https://www.geo.tv/assets/front/js/push_notification.js?v=1.4'];
#
#               var alljscustom = ['https://www.geo.tv/assets/front/ui/js/my.js?ver=32326','https://www.geo.tv/assets/front/js/mycustom.js?ver=656'];
#
#               setTimeout(function(){
#                   lazyloadjs.forEach(function (item,index) {
#                       var scriptElement=document.createElement('script');
#                       scriptElement.type = 'text/javascript';
#                       scriptElement.src = item;
#                       document.body.appendChild(scriptElement);
#                   });
#               }, 500);
#
#               setTimeout(function(){
#                   alljs.forEach(function (item,index) {
#                       var scriptElement=document.createElement('script');
#                       scriptElement.type = 'text/javascript';
#                       scriptElement.src = item;
#                       document.body.appendChild(scriptElement);
#                   });
#               }, 1000);
#
#               setTimeout(function(){
#                   firebaseappjs.forEach(function (item,index) {
#                       var scriptElement=document.createElement('script');
#                       scriptElement.type = 'text/javascript';
#                       scriptElement.src = item;
#                       document.body.appendChild(scriptElement);
#                   });
#               }, 2500);
#
#               setTimeout(function(){
#                   firebasejs.forEach(function (item,index) {
#                       var scriptElement=document.createElement('script');
#                       scriptElement.type = 'text/javascript';
#                       scriptElement.src = item;
#                       document.head.appendChild(scriptElement);
#                   });
#               }, 4000);
#
#               setTimeout(function(){
#                   firebasejs_tokenjs.forEach(function (item,index) {
#                                                 var scriptElement=document.createElement('script');
#                           scriptElement.type = 'text/javascript';
#                           scriptElement.src = item;
#                           document.head.appendChild(scriptElement);
#                                         });
#               }, 6000);
#
#               const jqueryIntervalcheck = setInterval(function () {
#                 if(typeof jQuery !== "undefined"){
#                     clearInterval(jqueryIntervalcheck);
#
#                     setTimeout(function(){
#                       alljscustom.forEach(function (item,index) {
#                             var scriptElement=document.createElement('script');
#                             scriptElement.type = 'text/javascript';
#                             scriptElement.src = item;
#                             document.body.appendChild(scriptElement);
#                       });
#                     }, 500);
#
#                                     }
#               },100);
#             };
#
#             var raf = window.requestAnimationFrame || window.mozRequestAnimationFrame ||
#             window.webkitRequestAnimationFrame || window.msRequestAnimationFrame;
#
#             var loadDeferredJSCaptcha = function() {
#                 var addJSNode = document.getElementById("captchejs");
#                 var replacement = document.createElement("div");
#                 replacement.innerHTML = addJSNode.textContent;
#                 document.body.appendChild(replacement);
#                 addJSNode.parentElement.removeChild(addJSNode);
#             };
#
#
#             window.addEventListener('load', loadDeferredJS);
#                             //window.addEventListener('load', loadDeferredJSCaptcha);
#
#                       </script>
# <script crossorigin="anonymous" data-cf-beacon='{"rayId":"8325650a6974c90c","b":1,"version":"2023.10.0","token":"8291e380a9fa4889a56779ece7862f9c"}' defer="" integrity="sha512-euoFGowhlaLqXsPWQ48qSkBSCFs3DPRyiwVu3FjR96cMPx+Fr+gpWRhIafcHwqwCqWS42RZhIudOvEI+Ckf6MA==" src="https://static.cloudflareinsights.com/beacon.min.js/v84a3a4012de94ce1a686ba8c167c359c1696973893317"></script>
# </body>
# </html>].
